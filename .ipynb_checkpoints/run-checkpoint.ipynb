# %%
import datetime
print datetime.datetime.now()

# %%
import pandas as pd
from google.cloud import bigquery as bq
import matplotlib as mp
import os
import smtplib
import csv
import sys
import datetime as dt
import sendgrid
import ipdb
import re
from sendgrid.helpers.mail import *
# %matplotlib inline
arg_file='/tmp/.args'
Empty_Files={}

def Send_Mail(start_date,end_date,client,message_file):
        with open (message_file,"r+") as fo:
            msg_list=fo.readlines()
        sg = sendgrid.SendGridAPIClient("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")
        from_email = Email("noreply@optimahub.com")
        to_email = Email("spillai@datalicious.com")
        subject = "Missing or Empty Files"
        if msg_list:
          message='Below Files are either empty or not created in GBQ for date range\
                   '+start_date+\
                   ' and '  + end_date+"\n"\
                   ' for '+client.upper()+"\n"+'\n'.join(msg_list)
        else:
          message='All files are available with data in date range '+start_date +' and '  + \
                   end_date+"\n"+' for '+client.upper()+"\n"
        content=Content("text/plain",message)
        mail = Mail(from_email, subject, to_email, content)
        response = sg.client.mail.send.post(request_body=mail.get())
       
def Data_Plot(row,df):
    if row['Plot_type']=='pie':
        ax=pd.pivot_table(df, index = 'campaign').plot(kind='pie',y='count'
                                                       ,figsize=(5,5),title=row['Title'])
        ax.set_aspect('equal')
    elif row['Plot_type']=='stack':
        if (df[list(df)[2]] == 0).all():
            print row['Description']+" Files not present to Plot " +row['Title']+"\n"
        else:
            ax=pd.pivot_table(df, index = list(df)[0], columns =list(df)[1], 
                              values =list(df)[2]).plot(kind = 'bar',title=row['Title'],
                                                        width=0.8,figsize=(15,7),stacked=True)
            ax.set_ylabel(list(df)[2],fontsize=16)
    else:
        if (df[list(df)[1]] == 0).all():
            print row['Description']+" Files not present to Plot " +row['Title']+"\n"
        else:
            ax=pd.pivot_table(df, index = list(df)[0],
                              values =list(df)[1]).plot(kind = 'bar',title=row['Title'],
                                                        width=0.2,color='purple',figsize=(15,7))
            ax.set_yscale('log',basey=10)
            #ax.set_yticklabels(ax.get_yticks())
            ax.set_ylabel(list(df)[1],fontsize=16)
    mp.pyplot.show()
            
            
def Create_Frame(clnt,start_date,end_date,start_date_string,end_date_string):
    print clnt
    client= bq.Client(clnt)
    fields=[];rows=[]
    with open("query.csv","r")  as fo:
        csvreader = csv.DictReader(fo)
        for row in csvreader:
          row['Query']=row['Query'].format(client=clnt,start_date=start_date,end_date=end_date,
                                           start_date_string=start_date_string,end_date_string=end_date_string)
          print row['Query']
          try:
            df=client.query(row['Query']).to_dataframe()
            if row['column']=='count': 
                missing_files=df.loc[df[row['column']] == 0]['date']
                Empty_Files[row['Description']]=list(missing_files)
            if df.empty:
                print row['Description']+" Files not present to Plot " +row['Title']+"\n"
                continue
            else:
                Data_Plot(row,df)
          except Exception as e:
            continue
    missing_files={k: v for k, v in Empty_Files.items() if v}
    return missing_files
    
    
def main():
    if os.path.isfile(arg_file):
        with open(arg_file,'r+') as fo:
            args = list(line for line in (val.rstrip() for val in fo) if line)   
        client=args[0]
        start_date=args[1] if len(args)>1 else (dt.datetime.now() 
                                                - dt.timedelta(11)).strftime('%Y-%m-%d')
        end_date=args[2] if len(args)>2  else (dt.datetime.now() 
                                               - dt.timedelta(4)).strftime('%Y-%m-%d')
        start_date_string = re.sub('-', '',start_date)
        end_date_string=re.sub('-','',end_date)        
    Empty_Files=Create_Frame(client,start_date,end_date,start_date_string,end_date_string)
    with open('message',"w+") as fo:
        for k,v in Empty_Files.items():
          fo.write(k+' for below dates '+'\n')
          for val in v:
                fo.write(str(val)+'\n')
    Send_Mail(start_date,end_date,client,'message')
if __name__=="__main__":
    main()
# Out:
# 20190201
# 20190228
# srprsme-192904
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.dc.enriched_*`
#   WHERE
#       _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.dc.enriched_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#   `srprsme-192904.dcm.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#    parse_date('%Y%m%d', _table_suffix)  AS date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.dcm.cost_*`
# WHERE
#  _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY 1
# 111
# 404 Not found: Dataset srprsme-192904:dcm was not found in location US
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.dcm_enriched_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#  parse_date('%Y%m%d', _table_suffix)  as date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.enriched_cost_data.dcm_enriched_*`
# WHERE
#   _table_suffix between '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 400 srprsme-192904:enriched_cost_data.dcm_enriched_* does not match any table.
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.dcm.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   sum(mediaCost) spend
# FROM
#   `srprsme-192904.dcm.cost_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:dcm was not found in location US
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.dcm_enriched_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   sum(media_cost) as spend
# FROM
#   `srprsme-192904.enriched_cost_data.dcm_enriched_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 400 srprsme-192904:enriched_cost_data.dcm_enriched_* does not match any table.
#
# SELECT
#   date,0 as count
# FROM
#  UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.facebook.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) AS date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.facebook.cost_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# order by 1
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.facebook_enriched_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#  parse_date('%Y%m%d', _table_suffix) as date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.enriched_cost_data.facebook_enriched_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.facebook.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#      CAST(date_start  AS DATE) as date,
#   sum(spend) as spend
# FROM
#   `srprsme-192904.facebook.cost_*`
# WHERE
#  _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.facebook_enriched_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   sum(media_cost) as spend
# FROM
#   `srprsme-192904.enriched_cost_data.facebook_enriched_*`
# WHERE
#  _table_suffix  between'20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.facebook.exposure_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) AS date,
#   COUNT(*) AS count
# FROM
#   `srprsme-192904.facebook.exposure_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.facebook.sync_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#  parse_date('%Y%m%d', _table_suffix)  AS date,
#   COUNT(*) AS count
# FROM
#   `srprsme-192904.facebook.sync_*`
# WHERE
#    _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# Facebook_sync Files not present to Plot Facebook Sync Data
#
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.kenshoo.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) AS date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.kenshoo.cost_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# order by 1
# 111
# 404 Not found: Dataset srprsme-192904:kenshoo was not found in location US
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.kenshoo.cost_*`
#   WHERE
#    _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix)  as date,
#   sum(cost) spend
# FROM
#   `srprsme-192904.kenshoo.cost_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:kenshoo was not found in location US
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.kenshoo.display_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   sum(cost) spend
# FROM
#   `srprsme-192904.kenshoo.display_*`
# WHERE
#  _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:kenshoo was not found in location US
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.kenshoo.display_*`
#   WHERE
#    _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   sum(cost) spend
# FROM
#   `srprsme-192904.kenshoo.display_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:kenshoo was not found in location US
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.adwords.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix)  as date,
#    count(*) as count
# FROM
#   `srprsme-192904.adwords.cost_*`
# WHERE
#   _table_suffix between '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.adwords.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix)  as date,
#    sum(Cost) as spend
# FROM
#   `srprsme-192904.adwords.cost_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.adwords.click_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#    count(*) as count
# FROM
#   `srprsme-192904.adwords.click_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 400 srprsme-192904:adwords.click_* does not match any table.
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.adwords.campaign_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#    count(*) as count
# FROM
#   `srprsme-192904.adwords.campaign_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 400 srprsme-192904:adwords.campaign_* does not match any table.
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.bing.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   count(*) as count
# FROM
#   `srprsme-192904.bing.cost_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# Bing_cost Files not present to Plot Bing Data
#
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.bing.cost_*`
#   WHERE
#    _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   count(*) as cnt
# FROM
#   `srprsme-192904.bing.cost_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# Bing_cost Files not present to Plot Bing Spend
#
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.criteo.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#    count(*) as count
# FROM
#   `srprsme-192904.criteo.cost_*`
# WHERE
#  _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:criteo was not found in location US
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.criteo.cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#  sum(cost) as spend
# FROM
#   `srprsme-192904.criteo.cost_*`
# WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:criteo was not found in location US
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.dcm.search_ads_campaign_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   count(*) as count
# FROM
#   `srprsme-192904.dcm.search_ads_campaign_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:dcm was not found in location US
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.search_ads_enriched_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.enriched_cost_data.search_ads_enriched_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 400 srprsme-192904:enriched_cost_data.search_ads_enriched_* does not match any table.
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.dcm.search_ads_campaign_*`
#   WHERE
#     _table_suffix between  '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   SUM(cost) as spend
# FROM
#   `srprsme-192904.dcm.search_ads_campaign_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:dcm was not found in location US
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.search_ads_enriched_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix)  as date,
#   sum(media_cost) as spend
# FROM
#   `srprsme-192904.enriched_cost_data.search_ads_enriched_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 400 srprsme-192904:enriched_cost_data.search_ads_enriched_* does not match any table.
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.dcm.search_ads_keyword_*`
#   WHERE
#    _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#  parse_date('%Y%m%d', _table_suffix) as date,
#   count(*) as count
# FROM
#   `srprsme-192904.dcm.search_ads_keyword_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:dcm was not found in location US
#
#  SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.shopping_enriched_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#  parse_date('%Y%m%d', _table_suffix) as date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.enriched_cost_data.shopping_enriched_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
#
# 111
# 400 srprsme-192904:enriched_cost_data.shopping_enriched_* does not match any table.
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.dcm.search_ads_keyword_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   SUM(cost) as spend
# FROM
#   `srprsme-192904.dcm.search_ads_keyword_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 404 Not found: Dataset srprsme-192904:dcm was not found in location US
#
#  SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.shopping_enriched_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix)  as date,
#   sum(media_cost) as spend
# FROM
#   `srprsme-192904.enriched_cost_data.shopping_enriched_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 400 srprsme-192904:enriched_cost_data.shopping_enriched_* does not match any table.
#
# SELECT
#   date,0 as spend
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.email_enriched_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   SUM(media_cost ) as spend
# FROM
#   `srprsme-192904.enriched_cost_data.email_enriched_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# 111
# 400 srprsme-192904:enriched_cost_data.email_enriched_* does not match any table.
#
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.cost_merged_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.enriched_cost_data.cost_merged_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   date,0 as count
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.aggregated_cost_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   COUNT(*) count
# FROM
#   `srprsme-192904.enriched_cost_data.aggregated_cost_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   date,0 as conversions
# FROM
#  UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.pathing.paths_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#    parse_date('%Y%m%d', _table_suffix) as date,
#   COUNT(DISTINCT path_id) as conversions
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
#   AND channel NOT IN('internal')
# GROUP BY 1
# ORDER BY
#   1
# SELECT
#   date,NULL as channel,0 as conversions
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.pathing.paths_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#    parse_date('%Y%m%d', _table_suffix) as date,
#   channel,
#   COUNT(DISTINCT path_id) as conversions
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
#   AND channel NOT IN('internal')
# GROUP BY
#   1,2
# ORDER BY
#   1
# SELECT
# path_length ,
# COUNT(DISTINCT path_id) count
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   DATE(event_time ) =DATE_SUB(current_date(), INTERVAL 4 DAY)
#   AND channel NOT IN('internal')
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#    path_length,
#   channel,
#   COUNT(DISTINCT path_id) count
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   DATE(event_time )=DATE_SUB(current_date(), INTERVAL 4 DAY)
#   AND channel NOT IN('internal')
#   --and path_length <50
# GROUP BY
#   1,2
# ORDER BY
#   1,2
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   channel,
#   SUM(media_cost) spend
# FROM
#   `srprsme-192904.enriched_cost_data.aggregated_cost_*`
# WHERE
#   _table_suffix BETWEEN '20190201'
#   AND '20190228'
#   AND channel NOT IN('internal')
# GROUP BY
#   1,
#   2
# ORDER BY
#   1,
#   2
# SELECT
#   date,0 as rev
# FROM
#   UNNEST(GENERATE_DATE_ARRAY('2019-02-01','2019-02-28')) AS date
#   where date not in ( SELECT
#     DISTINCT parse_date('%Y%m%d', _table_suffix) as st
#   FROM
#     `srprsme-192904.enriched_cost_data.aggregated_cost_revenue_*`
#   WHERE
#     _table_suffix BETWEEN '20190201'
#   AND '20190228')
#   group by 1
#   union all
# SELECT
#   parse_date('%Y%m%d', _table_suffix) as date,
#   SUM(revenue_weighted ) as rev
# FROM
#   `srprsme-192904.enriched_cost_data.aggregated_cost_revenue_*`
# WHERE
#  _table_suffix BETWEEN '20190201'
#   AND '20190228'
#   AND channel NOT IN('internal')
# GROUP BY
#   1
# ORDER BY
#   1
# SELECT
#   'null_campaign' as campaign,
#   COUNT(*) as count,
#   channel
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   campaign_name IS NULL and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 4 DAY)
#   and channel ='paid search'
#   group by channel
# UNION ALL
# SELECT
#   'total_campaign' as campaign,
#   COUNT(*),channel
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   1=1 and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 4 DAY)
#   and channel ='paid search'
#   group by channel
#   UNION ALL
# SELECT
#   'empty_campaign' as campaign,
#   COUNT(*),channel
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   campaign_name =''  and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 4 DAY)
#   and channel ='paid search'
#   group by channel
# SELECT
#   'null_campaign' as campaign,
#   COUNT(*) as count,
#   channel
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   campaign_name IS NULL and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 4 DAY)
#   and channel ='paid social'
#   group by channel
# UNION ALL
# SELECT
#   'total_campaign' as campaign,
#   COUNT(*),channel
# FROM
#  `srprsme-192904.pathing.paths_*`
# WHERE
#   1=1 and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 04 DAY)
#   and channel ='paid social'
#   group by channel
#   UNION ALL
# SELECT
#   'empty_campaign' as campaign,
#   COUNT(*),channel
# FROM
# `srprsme-192904.pathing.paths_*`
# WHERE
#   campaign_name =''  and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 04 DAY)
#   and channel ='paid social'
#   group by channel
# SELECT
#   'null_campaign' as campaign,
#   COUNT(*) as count,
#   channel
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   campaign_name IS NULL and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 04 DAY)
#   and channel ='display'
#   group by channel
# UNION ALL
# SELECT
#   'total_campaign' as campaign,
#   COUNT(*),channel
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   1=1 and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 04 DAY)
#   and channel ='display'
#   group by channel
#   UNION ALL
# SELECT
#   'empty_campaign' as campaign,
#   COUNT(*),channel
# FROM
# `srprsme-192904.pathing.paths_*`
# WHERE
#   campaign_name =''  and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 04 DAY)
#   and channel ='display'
#   group by channel
# Pathing_path Files not present to Plot   Null V/S Total campaign for channel Display
#
# SELECT
#   'null_campaign' as campaign,
#   COUNT(*) as count,
#   channel
# FROM
#   `srprsme-192904.pathing.paths_*`
# WHERE
#   campaign_name IS NULL and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 04 DAY)
#   and channel not in ('display','paid social','paid search')
#   group by channel
# UNION ALL
# SELECT
#   'total_campaign' as campaign,
#   COUNT(*),channel
# FROM
# `srprsme-192904.pathing.paths_*`
# WHERE
#   1=1 and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 04 DAY)
#   and channel not in ('display','paid social','paid search')
#   group by channel
#   UNION ALL
# SELECT
#   'empty_campaign' as campaign,
#   COUNT(*),channel
# FROM
#  `srprsme-192904.pathing.paths_*`
# WHERE
#   campaign_name =''  and DATE(event_time)=DATE_SUB(current_date(), INTERVAL 04 DAY)
#   and channel not in ('display','paid social','paid search')
#   group by channel
